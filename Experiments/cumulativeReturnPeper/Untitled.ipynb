# %%
import numpy as np
import pandas as pd
from technicalSignals import Indicators
import matplotlib.pyplot as plt

# %%
price = pd.read_csv('/home/simone/Desktop/NLFF/indexes/indexesAAPL.csv')
price.head()
# Out:
#    Unnamed: 0                 date     open      high     low    close  \
# 0           0  2015-02-02 15:00:00  118.050  118.3850  116.64  116.640
# 1           1  2015-02-02 16:00:00  116.660  117.4700  116.08  117.300
# 2           2  2015-02-02 17:00:00  117.290  118.3850  117.29  117.950
# 3           3  2015-02-02 18:00:00  117.945  118.0000  116.96  117.040
# 4           4  2015-02-02 19:00:00  117.040  117.5899  116.65  116.945
#
#     volume  close_12_ema  close_26_ema      macd     ...        macd.3  \
# 0  8630547    116.640000    116.640000  0.000000     ...      0.000000
# 1  9866725    116.997500    116.982692  0.014808     ...      0.014808
# 2  8393459    117.369261    117.330237  0.039024     ...      0.039024
# 3  5054623    117.265326    117.249099  0.016227     ...      0.016227
# 4  6240553    117.178295    117.178577 -0.000283     ...     -0.000283
#
#     macds.2   macds.3     boll_ub     boll_lb       rsi_6      rsi_12  \
# 0  0.000000  0.000000         NaN         NaN         NaN         NaN
# 1  0.008226  0.008226  117.903381  116.036619  100.000000  100.000000
# 2  0.020849  0.020849  118.606679  115.986654  100.000000  100.000000
# 3  0.019283  0.019283  118.332485  116.132515   52.356021   55.834176
# 4  0.013463  0.013463  118.161712  116.188288   49.407115   53.160281
#
#      vr_6_sma       wr_10        wr_6
# 0         NaN  100.000000  100.000000
# 1         NaN   47.071584   47.071584
# 2         NaN   18.872017   18.872017
# 3  361.257091   58.351410   58.351410
# 4  261.460327   62.472885   62.472885
#
# [5 rows x 25 columns]

# %%
ind = Indicators.aaron(price, 50)
f, axarr = plt.subplots(2)
f.set_figheight(7)
f.set_figwidth(10)
axarr[0].plot(price['close'])
axarr[1].plot(ind)
axarr[1].plot()

plt.show()
