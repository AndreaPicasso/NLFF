# %%
import pandas as pd
import re
from os import listdir
import numpy as np
from stockstats import StockDataFrame 
from googlefinance.client import get_price_data, get_prices_data, get_prices_time_data
files=list()
files=listdir(r"C:\Users\Utente\Desktop\NLFF\NLFF\intrinioDataset")
#print(files)
#for t in lista:
 #   t=re.sub('\.csv$', '', t)
  #  print(t)

#files=["AAL","FB"]
for file in files:
    print("Working on...")
    print(file)
    file=re.sub('\.csv$', '', file)
    print(file)

    param = {
    'q': file, # Stock symbol (ex: "AAPL")
    'i': "3600", # Interval size in seconds ("86400" = 1 day intervals)
    'x': "NASD", # INDEXNASDAQStock exchange symbol on which stock is traded (ex: "NASD")
    'p': "1Y" # Period (Ex: "1Y" = 1 year)
    }
   
    # link to doc http://www.networkerror.org/component/content/article/1-technical-wootness/44-googles-undocumented-finance-api.html
    # get price data (return pandas dataframe) 1465948800
    priceData = get_price_data(param)
    #print(priceData)
    stock = StockDataFrame.retype(priceData)
    #print(stock)
    toSave = pd.DataFrame(stock)
    idxs = np.array(['macd','macds', 'boll_ub', 'boll_lb','rsi_6','rsi_12','vr_6_sma','wr_10','wr_6'])
    #print(idxs)
    for index,x in np.ndenumerate(idxs):
    #print(x)
        toSave = pd.concat([toSave, pd.DataFrame(stock.get(x))], axis=1)
        
        #print(toSave)
        #dat1 = pd.DataFrame({'dat1': [9,5]})
        #toSave.join(pd.DataFrame({x:stock.get(x)}))
        #print("date"+toSave)
    if(len(toSave)>0):
        toSave.to_csv(r'C:\Users\Utente\Desktop\NLFF\NLFF\DataSetIndexes\indexes'+file+'.csv')
    else:
        print("Non trovato "+file)
# Out:
# Working on...
# AAPL.csv
# AAPL
# C:\Users\Utente\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Working on...
# ADBE.csv
# ADBE
# Working on...
# ADI.csv
# ADI
# Working on...
# ADP.csv
# ADP
# Working on...
# ADSK.csv
# ADSK
# Working on...
# AKAM.csv
# AKAM
# Working on...
# ALGN.csv
# ALGN
# Working on...
# ALL.csv
# ALL
# Non trovato ALL
# Working on...
# ALXN.csv
# ALXN
# Working on...
# AMAT.csv
# AMAT
# Working on...
# AMGN.csv
# AMGN
# Working on...
# AMZN.csv
# AMZN
# Working on...
# ATVI.csv
# ATVI
# Working on...
# AVGO.csv
# AVGO
# Working on...
# BIDU.csv
# BIDU
# Working on...
# BIIB.csv
# BIIB
# Working on...
# BMRN.csv
# BMRN
# Working on...
# CA.csv
# CA
# Working on...
# CELG.csv
# CELG
# Working on...
# CERN.csv
# CERN
# Working on...
# CHTR.csv
# CHTR
# Working on...
# CMCSA.csv
# CMCSA
# Working on...
# COST.csv
# COST
# Working on...
# CSCO.csv
# CSCO
# Working on...
# CSX.csv
# CSX
# Working on...
# CTAS.csv
# CTAS
# Working on...
# CTRP.csv
# CTRP
# Working on...
# CTSH.csv
# CTSH
# Working on...
# CTXS.csv
# CTXS
# Working on...
# DISCA.csv
# DISCA
# Working on...
# DISH.csv
# DISH
# Working on...
# DLTR.csv
# DLTR
# Working on...
# EA.csv
# EA
# Working on...
# EBAY.csv
# EBAY
# Working on...
# ESRX.csv
# ESRX
# Working on...
# EXPE.csv
# EXPE
# Working on...
# FAST.csv
# FAST
# Working on...
# FB.csv
# FB
# Working on...
# FISV.csv
# FISV
# Working on...
# FOXA.csv
# FOXA
# Working on...
# GILD.csv
# GILD
# Working on...
# GOOGL.csv
# GOOGL
# Working on...
# HAS.csv
# HAS
# Working on...
# HOLX.csv
# HOLX
# Working on...
# HSIC.csv
# HSIC
# Working on...
# IDXX.csv
# IDXX
# Working on...
# ILMN.csv
# ILMN
# Working on...
# INCY.csv
# INCY
# Working on...
# INTC.csv
# INTC
# Working on...
# INTU.csv
# INTU
# Working on...
# ISRG.csv
# ISRG
# Working on...
# JBHT.csv
# JBHT
# Working on...
# JD.csv
# JD
# Working on...
# KHC.csv
# KHC
# Working on...
# KLAC.csv
# KLAC
# Working on...
# LBTYA.csv
# LBTYA
# Working on...
# LRCX.csv
# LRCX
# Working on...
# MAR.csv
# MAR
# Working on...
# MAT.csv
# MAT
# Working on...
# MCHP.csv
# MCHP
# Working on...
# MDLZ.csv
# MDLZ
# Working on...
# MELI.csv
# MELI
# Working on...
# MNST.csv
# MNST
# Working on...
# MSFT.csv
# MSFT
# Working on...
# MU.csv
# MU
# Working on...
# MXIM.csv
# MXIM
# Working on...
# MYL.csv
# MYL
# Working on...
# NCLH.csv
# NCLH
# Non trovato NCLH
# Working on...
# NFLX.csv
# NFLX
# Working on...
# NTES.csv
# NTES
# Working on...
# NVDA.csv
# NVDA
# Working on...
# ORLY.csv
# ORLY
# Working on...
# PAYX.csv
# PAYX
# Working on...
# PCAR.csv
# PCAR
# Working on...
# PCLN.csv
# PCLN
# Working on...
# PYPL.csv
# PYPL
# Working on...
# QCOM.csv
# QCOM
# Working on...
# REGN.csv
# REGN
# Working on...
# ROST.csv
# ROST
# Working on...
# SBUX.csv
# SBUX
# Working on...
# SHPG.csv
# SHPG
# Working on...
# SIRI.csv
# SIRI
# Working on...
# STX.csv
# STX
# Working on...
# SWKS.csv
# SWKS
# Working on...
# SYMC.csv
# SYMC
# Working on...
# TMUS.csv
# TMUS
# Working on...
# TSCO.csv
# TSCO
# Working on...
# TSLA.csv
# TSLA
# Working on...
# TXN.csv
# TXN
# Working on...
# ULTA.csv
# ULTA
# Working on...
# VDC.csv
# VDC
# Non trovato VDC
# Working on...
# VIAB.csv
# VIAB
# Working on...
# VOD.csv
# VOD
# Working on...
# VRSK.csv
# VRSK
# Working on...
# VRTX.csv
# VRTX
# Working on...
# WBA.csv
# WBA
# Working on...
# WYNN.csv
# WYNN
# Working on...
# XLNX.csv
# XLNX
# Working on...
# XRAY.csv
# XRAY
