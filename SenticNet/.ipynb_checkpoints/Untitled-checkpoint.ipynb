# %%
import pysentiment as ps
import pandas as pd
from senticnet.senticnet import Senticnet
hiv4 = ps.HIV4()
tokens = hiv4.tokenize("how hare you? fine well. beautifull")
print(tokens)


sn = Senticnet()
concept_info = sn.concept('love')
polarity_value = sn.polarity_value('love')
polarity_intense = sn.polarity_intense('love')
moodtags = sn.moodtags('love')
semantics = sn.semantics('love')
sentics = sn.sentics('love')
#score = hiv4.get_score(tokens)
print(concept_info)
print(polarity_value)
print(polarity_intense)
print(moodtags )
print(semantics)
print(sentics)


#print(score)
#subjec,10000)
#f_score=np.multiply(score['Polarity'],sub)
#f_score=np.multiply(f_score,0.001)
#sentiment=np.append(sentiment,f_score)
##
#summary = TextBlob(data[i]['summary']).sentiment
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f09700048be1> in <module>()
#       1 import pysentiment as ps
#       2 import pandas as pd
# ----> 3 from senticnet.senticnet import Senticnet
#       4 hiv4 = ps.HIV4()
#       5 tokens = hiv4.tokenize("how hare you? fine well. beautifull")
#
# ModuleNotFoundError: No module named 'senticnet'
