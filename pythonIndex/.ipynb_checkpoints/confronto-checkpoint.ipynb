# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing


indexes = pd.read_csv('indexes.csv')

indexes.head()
# Out:
#                   date    open     high     low     close   volume  \
# 0  2017-03-09 15:40:00  138.74  138.790  137.05  137.8752  3438589
# 1  2017-03-09 16:00:00  137.86  138.480  137.86  138.4400  2206173
# 2  2017-03-09 16:20:00  138.44  138.715  138.36  138.4500  1434425
# 3  2017-03-09 16:40:00  138.45  138.700  138.35  138.5350   798608
# 4  2017-03-09 17:00:00  138.53  138.700  138.40  138.6450   629192
#
#    close_12_ema  close_26_ema      macd     macds     macdh    macd.1  \
# 0    137.875200    137.875200  0.000000  0.000000  0.000000  0.000000
# 1    138.181133    138.168462  0.012672  0.007040  0.011264  0.012672
# 2    138.286072    138.269616  0.016456  0.010899  0.011115  0.016456
# 3    138.364649    138.343805  0.020843  0.014268  0.013151  0.020843
# 4    138.440819    138.413654  0.027166  0.018105  0.018122  0.027166
#
#     macds.1     boll_ub     boll_lb  rsi_6  rsi_12  vr_6_sma      wr_10  \
# 0  0.000000         NaN         NaN    NaN     NaN       NaN  52.574713
# 1  0.007040  138.956348  137.358852  100.0   100.0       NaN  20.114943
# 2  0.010899  138.913091  137.597042  100.0   100.0       NaN  19.540230
# 3  0.014268  138.930877  137.719223  100.0   100.0       NaN  14.655172
# 4  0.018105  138.986672  137.791408  100.0   100.0       NaN   8.333333
#
#         wr_6
# 0  52.574713
# 1  20.114943
# 2  19.540230
# 3  14.655172
# 4   8.333333

# %%
#Normalizing indexes

values = {'boll_ub': 138, 'boll_lb': 137}
indexes = indexes.fillna(value=values)
indexes = indexes.fillna(0)

x = indexes[['high','boll_ub','boll_lb']].values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
indexes[['high','boll_ub','boll_lb']] = pd.DataFrame(x_scaled)

indexes[['high','boll_ub','boll_lb']] -= [0.62,0.62,0.62]


plt.figure(figsize=(20,10))
plt.plot(indexes['high'].tolist(),'b')
#Media mobile anche sugli indici
indexes[['high','boll_ub','boll_lb']] = indexes[['high','boll_ub','boll_lb']].rolling(window=100).mean()

plt.plot(indexes['high'].tolist(),'r')



plt.show()

# %%
sentimentTextBlob = pd.read_csv('../sentiment/textBlob/sentiment20minutes.csv')
meanSentiment = sentimentTextBlob['sentiment'].mean()
meanSentimentWeighted = sentimentTextBlob['sentimentWeighted'].mean()

sentimentTextBlob['sentiment'] -= meanSentiment
sentimentTextBlob['sentimentWeighted'] -= meanSentimentWeighted




sentimentTextBlob.head()
# Out:
#               initTime  sentimentWeighted  sentiment
# 0  2017-10-03 20:00:00           0.198133   0.193894
# 1  2017-10-03 20:20:00           0.192774   0.102732
# 2  2017-10-03 20:40:00           0.219245   0.200396
# 3  2017-10-03 21:00:00           0.114388  -0.006212
# 4  2017-10-03 21:20:00           0.114388  -0.006212

# %%
# Dataset allignment in time
indexes = indexes[indexes['date'] >= sentimentTextBlob['initTime'][0]]
#sentimentTextBlob = sentimentTextBlob[sentimentTextBlob['initTime'] < indexes['Unnamed: 0'][len(indexes)-1]]

indexes.head()
# Out:
#                      date      open      high      low   close  volume  \
# 2884  2017-10-03 20:00:00  154.6562 -0.248874  154.580  154.74  265000
# 2885  2017-10-03 20:20:00  154.7400 -0.248612  154.735  154.86  497192
# 2886  2017-10-03 20:40:00  154.8500 -0.248376  154.730  154.73  369223
# 2887  2017-10-03 21:00:00  154.7300 -0.248103  154.640  154.74  356625
# 2888  2017-10-03 21:20:00  154.7490 -0.247880  154.560  154.56  468340
#
#       close_12_ema  close_26_ema      macd     macds     macdh    macd.1  \
# 2884    154.554192    154.267527  0.286665  0.271443  0.030444  0.286665
# 2885    154.601240    154.311414  0.289825  0.275119  0.029412  0.289825
# 2886    154.621049    154.342421  0.278628  0.275821  0.005614  0.278628
# 2887    154.639349    154.371871  0.267478  0.274152 -0.013349  0.267478
# 2888    154.627142    154.385806  0.241335  0.267589 -0.052508  0.241335
#
#        macds.1   boll_ub   boll_lb      rsi_6     rsi_12    vr_6_sma  \
# 2884  0.271443 -0.240550 -0.247594  63.475056  63.193542  177.769164
# 2885  0.275119 -0.240378 -0.246693  69.543257  65.767924  192.871175
# 2886  0.275821 -0.240216 -0.245840  57.191113  60.746564  206.604345
# 2887  0.274152 -0.240056 -0.245033  57.881665  60.996459  221.215035
# 2888  0.267589 -0.239901 -0.244287  42.925211  54.218661  230.310084
#
#           wr_10       wr_6
# 2884  40.229885  60.869565
# 2885  30.263158  21.322691
# 2886  54.127199  50.969213
# 2887  52.623666  48.688712
# 2888  92.173913  89.737742

# %%
print(len(sentimentTextBlob['initTime'].tolist()))
print(len(indexes['date'].tolist()))
# Out:
# 2106
# 2126

# %%
plt.figure(figsize=(20,10))
plt.plot(indexes['high'].tolist(),'b',sentimentTextBlob['sentiment'].tolist(),'r',)
plt.title('Only Sentiment')
plt.show()

# %%
plt.figure(figsize=(20,10))
#plt.plot(indexes['high'],'b',indexes['boll_ub'],'r',indexes['boll_lb'],'g')
plt.plot(indexes['high'].tolist(),'b',sentimentTextBlob['sentimentWeighted'].tolist(),'r',)
plt.title('Weighted Sentiment')
plt.show()

# %%
sentiment5 = sentimentTextBlob['sentiment'].rolling(window=5).mean()
sentiment15 = sentimentTextBlob['sentiment'].rolling(window=15).mean()
sentiment30 = sentimentTextBlob['sentiment'].rolling(window=30).mean()
sentiment50 = sentimentTextBlob['sentiment'].rolling(window=50).mean()
sentiment100 = sentimentTextBlob['sentiment'].rolling(window=100).mean()


plt.figure(figsize=(20,10))
#plt.plot(indexes['high'],'b',indexes['boll_ub'],'r',indexes['boll_lb'],'g')
plt.plot(indexes['high'].tolist(),'b',sentiment100,'y',sentiment50,'c',np.zeros(len(sentiment30)),'r')
plt.title('Comparison between moving averages')
plt.show()


sentimentTextBlob['sentiment'] = sentimentTextBlob['sentiment'].rolling(window=35).mean()
sentimentTextBlob['sentimentWeighted'] = sentimentTextBlob['sentimentWeighted'].rolling(window=35).mean()

# %%
plt.figure(figsize=(20,10))
#plt.plot(indexes['high'],'b',indexes['boll_ub'],'r',indexes['boll_lb'],'g')
plt.plot(indexes['high'].tolist(),'b',sentimentTextBlob['sentiment'].tolist(),'r',)
plt.title('Only Sentiment Moving Average')
plt.show()

# %%
plt.figure(figsize=(20,10))
#plt.plot(indexes['high'],'b',indexes['boll_ub'],'r',indexes['boll_lb'],'g')
plt.plot(indexes['high'].tolist(),'b',sentimentTextBlob['sentimentWeighted'].tolist(),'r',)
plt.title('Sentiment Weighted Moving Average')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(sentimentTextBlob['sentimentWeighted'].tolist(),'b',sentimentTextBlob['sentiment'].tolist(),'r',)
plt.show()

# %%
#Visto che sono simili d'ora in poi considero solo sentiment normale
 #Derivata

slopeStock = pd.Series(np.gradient(indexes['high']))
accuracy = [a*b*1000 for a,b in zip(slopeStock,sentiment100)]


plt.figure(figsize=(20,10))
plt.plot(indexes['high'].tolist(),'b',sentiment100,'y',accuracy,'g',np.zeros(len(sentiment30)),'r')
plt.show()
