# %%
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
df = pd.read_csv('indexes.csv')
 #, t, t**2, 'bs', t, t**3, 'g^'
plt.figure(figsize=(20,10))
plt.plot(df['high'],'b',df['boll_ub'],'r',df['boll_lb'],'g')
plt.ylabel('some numbers')
plt.show()
