# %%
import concept_parser

# %%
import pandas as pd
import numpy as np

# %%
tickers = ['AAPL', 'ADBE', 'ADI', 'ADP', 'ADSK', 'AKAM', 'ALGN',
          'ALXN', 'AMAT', 'AMGN', 'AMZN', 'ATVI', 'AVGO', 'BIDU',
          'BIIB', 'BMRN', 'CA', 'CELG', 'CERN', 'CHTR', 'CMCSA',
          'COST', 'CSCO', 'CSX', 'CTAS', 'CTRP', 'CTSH', 'CTXS',
          'DISCA', 'DISH', 'DLTR', 'EA', 'EBAY', 'ESRX', 'EXPE',
          'FAST', 'FB', 'FISV', 'FOXA', 'GILD', 'GOOGL', 'HAS',
          'HOLX', 'HSIC', 'IDXX', 'ILMN', 'INCY', 'INTC', 'INTU',
          'ISRG', 'JBHT', 'JD', 'KHC', 'KLAC', 'LBTYA', 'LRCX', 'MAR',
          'MAT', 'MCHP', 'MDLZ', 'MELI', 'MNST', 'MSFT', 'MU', 'MXIM',
          'MYL', 'NFLX', 'NTES', 'NVDA', 'ORLY', 'PAYX', 'PCAR', 'PCLN',
          'PYPL', 'QCOM', 'REGN', 'ROST', 'SBUX', 'SHPG', 'SIRI', 'STX',
          'SWKS', 'SYMC', 'TMUS', 'TSCO', 'TSLA', 'TXN', 'ULTA', 'VIAB',
          'VOD', 'VRSK', 'VRTX', 'WBA', 'WYNN', 'XLNX', 'XRAY']

# %%
tickers = ['AAPL']
for ticker in tickers:
    print(ticker)
    news = pd.read_csv('/home/simone/Scrivania/NLFF/intrinioDataset/'+ticker+'.csv')

    concept_parser.parse(news, 'SUMMARY' , 'concepts')
    news.head()
    #news.to_csv(path_or_buf=None, columns=

# %%
news.head()
# Out:
#   TICKER FIGI_TICKER          FIGI  \
# 0   AAPL     AAPL:UW  BBG000B9Y5X2
# 1   AAPL     AAPL:UW  BBG000B9Y5X2
# 2   AAPL     AAPL:UW  BBG000B9Y5X2
# 3   AAPL     AAPL:UW  BBG000B9Y5X2
# 4   AAPL     AAPL:UW  BBG000B9Y5X2
#
#                                                TITLE  \
# 0  These 3 Dow Jones Stocks Are Near Buy Points A...
# 1  [$$] More of Apple's suppliers fell short of i...
# 2  Apple finds more serious supplier problems as ...
# 3  Apple finds more serious supplier problems as ...
# 4  Apple Push to Clean Up Supply Chain Gained Mom...
#
#             PUBLICATION_DATE  \
# 0  2018-03-08 05:35:58 +0000
# 1  2018-03-08 03:26:17 +0000
# 2  2018-03-08 03:01:54 +0000
# 3  2018-03-08 02:55:28 +0000
# 4  2018-03-08 02:08:18 +0000
#
#                                                  URL  \
# 0  http://finance.yahoo.com/r/2e568d6b-3fd9-33f6-...
# 1  http://finance.yahoo.com/r/cf3dc575-b05e-3afb-...
# 2  https://finance.yahoo.com/news/apple-finds-sup...
# 3  https://finance.yahoo.com/news/apple-finds-sup...
# 4  http://finance.yahoo.com/r/66f4764e-aaec-36d0-...
#
#                                              SUMMARY  \
# 0  The Dow Jones is lagging on Trump tariff fears...
# 1  More employees of Apple's manufacturing suppli...
# 2  The latest annual supplier responsibility repo...
# 3  The latest annual supplier responsibility repo...
# 4  Apple Inc. touted major improvements in labor ...
#
#                                             concepts
# 0  [Jones, Dow_Jones, Jones_lag, fears_Trump, tar...
# 1  [e, A, m, s, c, r, w, h, o, y, p, d, i, More_e...
# 2  [[report], [latest_report], [annual_report], [...
# 3  [[report], [latest_report], [annual_report], [...
# 4  [Apple_Inc., Inc._tout, major_improvements, to...

# %%
news.to_csv("AAPL.csv", columns=['PUBLICATION_DATE', 'SUMMARY', 'concepts'])

# %%
news.tail()
# Out:
#      TICKER FIGI_TICKER          FIGI  \
# 9995   AAPL     AAPL:UW  BBG000B9Y5X2
# 9996   AAPL     AAPL:UW  BBG000B9Y5X2
# 9997   AAPL     AAPL:UW  BBG000B9Y5X2
# 9998   AAPL     AAPL:UW  BBG000B9Y5X2
# 9999   AAPL     AAPL:UW  BBG000B9Y5X2
#
#                                                   TITLE  \
# 9995  Last Year&apos;s iPhones Seen As Better Deal T...
# 9996  European Union Stepping Up Tax Battles Vs. Ama...
# 9997  How Banning Arista Products Could Help Cisco S...
# 9998                Keep a Finger in Smartphone Sensors
# 9999  This author thinks Amazon could break up to ke...
#
#                PUBLICATION_DATE  \
# 9995  2017-10-03 20:23:18 +0000
# 9996  2017-10-03 20:21:06 +0000
# 9997  2017-10-03 20:02:35 +0000
# 9998  2017-10-03 20:00:11 +0000
# 9999  2017-10-03 19:55:49 +0000
#
#                                                     URL  \
# 9995  http://finance.yahoo.com/r/1df07879-e373-35bf-...
# 9996  http://finance.yahoo.com/r/d0b57822-36f4-3925-...
# 9997  http://finance.yahoo.com/r/90681246-4ff7-3ef2-...
# 9998  http://finance.yahoo.com/r/0bf9597a-0d59-3cf8-...
# 9999  http://finance.yahoo.com/r/d45817b8-143f-374f-...
#
#                                                 SUMMARY  \
# 9995  Reports indicate that many Apple customers are...
# 9996  The European Union appears set to escalate tax...
# 9997  Cisco Systems (CSCO) and Arista Networks (ANET...
# 9998  Suppliers have to translate demand into earnin...
# 9999  Given the awesome power of the internet's 'Fou...
#
#                                                concepts
# 9995  [[Reports_indicate], [many_customers], [Apple_...
# 9996  [Union, European_Union, Union_appear, appear_s...
# 9997  [Cisco_Systems, Systems_have, Arista_Networks,...
# 9998  [[Suppliers_have], [translate], [translate_dem...
# 9999  [[power], [awesome_power], [internet], [power_...
