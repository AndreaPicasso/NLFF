# %%
from plotHelperFunction import comparisonInfo

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from datetime import datetime, timedelta

# %%
dic = comparisonInfo('indexes.csv', 'sentiment20minutes.csv', 'sentiment', 'initTime', 100, 100)

plt.figure(figsize=(20,10))
plt.plot(dic['priceAverageMean'],'b',dic['sentimentAverageMean'],'y',dic['accuracy'],'g',dic['zeros'],'r')
plt.show()
# Out:
# Reading index file indexes.csv
