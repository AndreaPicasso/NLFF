# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
files=['AAPL','AMZN','PEP','GOOGL','MSFT','FB','INTC','CSCO','CMCSA','NVDA','NFLX','BKNG','ADBE','AMGN','TXN','AVGO','PYPL','GILD','COST','QCOM']       
#files=['AAPL','AMZN','GOOGL','MSFT','FB','INTC','CSCO','CMCSA','NVDA','NFLX']

# %%
histo=np.zeros(99)
for file in files:
    prediction=pd.read_csv('/home/andrea/Desktop/NLFF/technicalAnalysis/NN/Predictions/Affective/gscore-1000/both/'+file+'.csv')
    temp,b,p=plt.hist(prediction[file], bins = np.arange(0.0, 1.0, 0.01))
    histo=histo+temp
    plt.show()
print('==========================================')

plt.plot(histo)
plt.show()
